# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0497/10-03-2020-new/blob/master/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
std=pd.read_csv("students_placement_data (1).csv")
std
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
std.describe()
# Out:
#           Roll No  SSC Percentage  ...  B.Tech_percentage    Backlogs
# count  117.000000      117.000000  ...         117.000000  117.000000
# mean    59.000000       80.324359  ...          62.943419    4.111111
# std     33.919021        8.879266  ...          12.064306    6.335148
# min      1.000000       47.800000  ...          31.200000    0.000000
# 25%     30.000000       76.000000  ...          54.180000    0.000000
# 50%     59.000000       82.330000  ...          64.360000    0.000000
# 75%     88.000000       87.000000  ...          72.570000    7.000000
# max    117.000000       93.660000  ...          88.100000   25.000000
#
# [8 rows x 5 columns]

# %%
std=std.loc[std['Gender']=='F'] #we split the datafor female students
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 7          8      F  ...                                 NO        Not placed
# 10        11      F  ...                                 NO            Placed
# 13        14      F  ...                                yes            Placed
# 15        16      F  ...                                yes            Placed
# 16        17      F  ...                                yes        Not placed
# 17        18      F  ...                                yes            Placed
# 18        19      F  ...                                yes            Placed
# 22        23      F  ...                                yes        Not placed
# 28        29      F  ...                                yes        Not placed
# ...

# %%
std.plot(x='inter_Diploma_percentage',y='B.Tech_percentage',style='o')#we plot a scatter plot for percentages of female students

# %%
std=pd.read_csv("students_placement_data (1).csv")
std
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
std=std.loc[std['Gender']=='M'] #we split the  data of male students
std
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# 5          6      M  ...                                yes        Not placed
# 6          7      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [68 rows x 9 columns]

# %%
std.describe()
# Out:
#           Roll No  SSC Percentage  ...  B.Tech_percentage    Backlogs
# count  117.000000      117.000000  ...         117.000000  117.000000
# mean    59.000000       80.324359  ...          62.943419    4.111111
# std     33.919021        8.879266  ...          12.064306    6.335148
# min      1.000000       47.800000  ...          31.200000    0.000000
# 25%     30.000000       76.000000  ...          54.180000    0.000000
# 50%     59.000000       82.330000  ...          64.360000    0.000000
# 75%     88.000000       87.000000  ...          72.570000    7.000000
# max    117.000000       93.660000  ...          88.100000   25.000000
#
# [8 rows x 5 columns]

# %%
std.plot(x='inter_Diploma_percentage',y='B.Tech_percentage',style='o')#we plot a scatter plot for percentages of male students

# %%
std=pd.read_csv("students_placement_data (1).csv")
std
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
std.plot(x='SSC Percentage',y='inter_Diploma_percentage',style='o')# plot  a scatter plot between ssc percentage and inter diploma percentage

# %%
X=std[['Roll No','SSC Percentage','inter_Diploma_percentage','Backlogs']].values
y=std['B.Tech_percentage'].values#declaring x and y data for linear regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model=LinearRegression() #apply linear regression on data ,here we have multivariate linearregression

# %%
model.fit(X_train,y_train)#using fit  after linear regression
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.intercept_#find y intercept of the fitting line
# Out:
# 37.60290161804113

# %%
model.coef_#to find slope of the multivariateregression lines
# Out:
# array([-0.02134442,  0.05955321,  0.33090571, -1.18650949])

# %%
std=pd.read_csv("students_placement_data (1).csv")
std
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 0          1      M  ...                                 NO        Not placed
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 3          4      M  ...                                yes        Not placed
# 4          5      M  ...                                yes        Not placed
# ..       ...    ...  ...                                ...               ...
# 112      113      M  ...                                 NO        Not placed
# 113      114      M  ...                                 NO        Not placed
# 114      115      M  ...                                 NO        Not placed
# 115      116      M  ...                                 NO        Not placed
# 116      117      M  ...                                 NO        Not placed
#
# [117 rows x 9 columns]

# %%
x=std['inter_Diploma_percentage'].values.reshape(-1,1)
y=std['B.Tech_percentage'].values.reshape(-1,1)

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.intercept_
# Out:
# array([-0.29734383])

# %%
model.coef_
# Out:
# array([[0.77207315]])

# %%
pred=model.predict([[72]])#predicting b.tech percentage from inter percentage of 72% for male students 
pred
# Out:
# array([[55.2919233]])

# %%
std=std.loc[std['Gender']=='F'] #we split the  data of male students
std
# Out:
#      Roll No Gender  ... registered_for_ Placement_Training  placement status
# 1          2      F  ...                                yes            Placed
# 2          3      F  ...                                yes        Not placed
# 7          8      F  ...                                 NO        Not placed
# 10        11      F  ...                                 NO            Placed
# 13        14      F  ...                                yes            Placed
# 15        16      F  ...                                yes            Placed
# 16        17      F  ...                                yes        Not placed
# 17        18      F  ...                                yes            Placed
# 18        19      F  ...                                yes            Placed
# 22        23      F  ...                                yes        Not placed
# 28        29      F  ...                                yes        Not placed
# ...

# %%
std.describe()
# Out:
#           Roll No  SSC Percentage  ...  B.Tech_percentage   Backlogs
# count   49.000000       49.000000  ...          49.000000  49.000000
# mean    58.142857       82.911633  ...          71.199388   0.714286
# std     31.077189        8.040363  ...           7.686968   2.140872
# min      2.000000       50.660000  ...          45.260000   0.000000
# 25%     33.000000       80.300000  ...          65.700000   0.000000
# 50%     61.000000       84.840000  ...          72.400000   0.000000
# 75%     85.000000       87.420000  ...          75.960000   0.000000
# max    105.000000       93.660000  ...          88.100000  13.000000
#
# [8 rows x 5 columns]

# %%
x=std['inter_Diploma_percentage'].values.reshape(-1,1)
y=std['B.Tech_percentage'].values.reshape(-1,1)

# %%
x.shape
# Out:
# (49, 1)

# %%
y.shape
# Out:
# (49, 1)

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=213)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.intercept_
# Out:
# array([21.59392118])

# %%
model.coef_
# Out:
# array([[0.58396655]])

# %%
model.predict([[72]])#predicting b.tech percentage for inter percentage of 72% of female students
# Out:
# array([[63.63951255]])

# %% [markdown]
# femALE STUDENTS ARE PERFORMING BETTER IN BTECH WITH 72% IN INTERMEDIATE
